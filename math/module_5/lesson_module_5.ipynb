# %% [markdown]
# # The curse of math - module 5: exersices from lessons
# # Апроксимация

# %%
from sympy import *
from sympy.plotting import plot
init_printing(use_unicode=False, wrap_line=False, no_global=True)

# %%
a1, a0, x = symbols('a1, a0, x')
equation1_lp = 100*a1 + a0
equation2_lp = 600*a1 + a0 - 550

# %%
nonlinsolve([equation1_lp, equation2_lp], [a1, a0])
# Out:
#   11
# {(--, -110)}
#   10

# %%
f = 1.1*x - 110
f
# Out:
# 1.1*x - 110

# %%
f.subs(x, 500)
# Out:
# 440.000000000000

# %% [markdown]
# ### Homework 5.2
#
# Практическое задание.<br>
# Для того, чтобы закрепить материал, посчитайте значение среднеквадратичной
# ошибки для данных наборов точек и аппроксимирующих функций. Постройте графики
# этих функций и отметьте данные точки на нем, чтобы посмотреть, как проходит через них
# график аппроксимирующей функции. При решении можете пользоваться python и
# matplotlib, а можете по-старинке, сделать это на бумаге, хотя это будет не слишком
# удобно.
# <br>
# 1.2.1.Начальный уровень.<br>
# (2; 12.258), (4; 17.24), (8; 30.151).<br>
# <br>
# f (x) = 3x + 5.<br>
# <br>
# (2; 3.688), (4; 10.791), (8; 20.705).<br>
# <br>
# f (x) = 0.25x2 + 0.75x + 1.25.<br>
# <br>
# Средний уровень.<br>
# (2; 4.872), (4; 29.707), (8; 246.971), (10; 485.727), (12; 840.658).<br>
# <br>
# f (x) = 0.5x3 − 0.25x2 + 0.75x + 1.25.<br>

# %%
f = 3*x + 5
f
# Out:
# 3*x + 5

# %%
plot(f)

# %%
f.subs(x, 2), f.subs(x, 4), f.subs(x, 8)
# Out:
# (11, 17, 29)

# %%
x = [2, 4, 8]
y = [12.258, 17.240, 30.151]

# %%
import numpy as np
import matplotlib.pyplot as plt

x_range = np.linspace(-10, 10, num=100)
f = lambda x: 3*x + 5
plt.scatter(x, y, c='r')
plt.axhline(0, color='black')
plt.axvline(0, color='black')
plt.plot(x_range, f(x_range))

# %%
n = 3
function_for_mse = lambda i: y[i] - f(x[i])
MSE = sum([function_for_mse(index)**2 for index in range(0, n)]) / n
RMSE = sqrt(MSE)

# %%
MSE, RMSE
# Out:
# (0.9883216666666655, 0.994143685121354)

# %% [markdown]
# ###  (2; 3.688), (4; 10.791), (8; 20.705).
#
# f (x) = 0.25*x2 + 0.75x + 1.25.

# %%
x = Symbol('x')
f = 0.25*x**2 + 0.75*x + 1.25
f
# Out:
#       2
# 0.25*x  + 0.75*x + 1.25

# %%
plot(f)

# %%
x = [2, 4, 8]
y = [3.688, 10.791, 20.705]

# %%
import numpy as np
import matplotlib.pyplot as plt

x_range = np.linspace(-10, 10, num=100)
f = lambda x: 0.25*x**2 + 0.75*x + 1.25
plt.scatter(x, y, c='r')
plt.axhline(0, color='black')
plt.axvline(0, color='black')
plt.plot(x_range, f(x_range))

# %%
function_for_mse = lambda i: y[i] - f(x[i])
MSE = sum([function_for_mse(index)**2 for index in range(0, len(y))])/len(y)
RMSE = sqrt(MSE)
MSE, RMSE
# Out:
# (4.31251666666667, 2.07665997858741)

# %% [markdown]
# ### Средний уровень.
# (2; 4.872), (4; 29.707), (8; 246.971), (10; 485.727), (12; 840.658).
#
# f (x) = 0.5x3 − 0.25x2 + 0.75x + 1.25.

# %%
from sympy import *
from sympy.plotting import plot
init_printing(use_unicode=False, wrap_line=False, no_global=True)

x = Symbol('x')

# %%
f = 0.5*x**3 - 0.25*x**2 + 0.75*x + 1.25
f
# Out:
#      3         2
# 0.5*x  - 0.25*x  + 0.75*x + 1.25

# %%
x = [2, 4, 8, 10, 12]
y = [4.872, 29.707, 246.971, 485.727, 840.658]

# %%
plot(f)

# %%
import numpy as np
import matplotlib.pyplot as plt

x_range = np.linspace(-14, 14, num=100)
f = lambda x: 0.5*x**3 - 0.25*x**2 + 0.75*x + 1.25
plt.scatter(x, y, c='r')
plt.axhline(0, color='black')
plt.axvline(0, color='black')
plt.plot(x_range, f(x_range))

# istall predicted points

# %%
f_for_mse = lambda i: y[i] - f(x[i])
MSE = sum([f_for_mse(index)**2 for index in range(0, len(y))])/len(y)
RMSE = sqrt(MSE)
MSE, RMSE

# found mean squared error for us function and root meat squared error
# Out:
# (3.404513399999994, 1.84513235297634)

# %% [markdown]
# ## lesson 5.3 - left shift and right shift

# %%
from sympy import *
from sympy.plotting import plot
import numpy as np
import matplotlib.pyplot as plt
init_printing(use_unicode=False, wrap_line=False, no_global=True)

# %%
def print_points_ands_function(sympy_function):
    def function(x_): return float(sympy_function.subs(x, x_))
    
    points_X = np.array([-3, -2, -1, 1, 2, 3])
    points_Y = np.array([15.0, 8.0, 13.0, 10.0, 15.0, 30.0])
    plt.xlim(-25, 7.5)
    plt.ylim(-1, 40)
    
    plt.scatter(points_X, points_Y, c='r')
    x_range = np.linspace(plt.xlim()[0], plt.xlim()[1], num=100)
    function_Y = [function(x_) for x_ in x_range]
    plt.plot(x_range, function_Y, 'b')
    plt.show()
    
    MSE = sum([(points_Y[index] - function(points_X[index]))**2 for index in range(len(points_Y))]) / len(points_Y)
    print(f'MSE = {MSE}')

# %%
x = Symbol('x')
f = x**2 + 32*x +265
f
# Out:
#  2
# x  + 32*x + 265

# %%
# found the mean squared error
print_points_ands_function(f)
# Out:
# MSE = 68981.16666666667

# %%
f = x**2
f
# Out:
#  2
# x

# %%
# check parity our function
f == f.subs(x, -x)
# Out:
# True

# %%
f = x**3
f
# Out:
#  3
# x

# %%
f == f.subs(x, -x)
# Out:
# False

# %%
f_new = f.subs(x, x-20)
f_new
# Out:
#                2
# 32*x + (x - 20)  - 375

# %%
# Easy to our unction with method of expand
f_new = expand(f_new)
f_new
# Out:
#  2
# x  - 8*x + 25

# %%
print_points_ands_function(f_new)
# Out:
# MSE = 687.8333333333334

# %%
f_new2 = expand(f_new.subs(x, x+5))
f_new2
# Out:
#  2
# x  + 2*x + 10

# %%
print_points_ands_function(f_new2)
# Out:
# MSE = 11.166666666666666

# %% [markdown]
# ### homework lesson 5.3

# %% [markdown]
# ### 1)Need to get value less 110

# %%
from sympy import *
from sympy.plotting import plot
import numpy as np
import matplotlib.pyplot as plt
init_printing(use_unicode=False, wrap_line=False, no_global=True)

# %%
def print_points_its_function(sympy_function):
    def function(x_): return float(sympy_function.subs(x, x_))
    
    points_X = np.array([-3, -2, -1, 1, 2, 3])
    points_Y = np.array([60, 30, 19, -16, -37, -23])
    
    plt.xlim(-15, 15)
    plt.ylim(-40, 80)
    
    plt.scatter(points_X, points_Y, c='r')
    x_range = np.linspace(plt.xlim()[0], plt.xlim()[1], num=100)
    function_Y = [function(x_) for x_ in x_range]
    plt.plot(x_range, function_Y, 'b')
    plt.show()
    
    MSE = sum([(points_Y[i] - function(points_X[i]))**2 for i in range(len(points_Y))]) / len(points_Y)
    print(f'MSE = {MSE}')

# %%
x = Symbol('x')
f1 = - 14 * x - 100
f1
# Out:
# -14*x - 100

# %%
print_points_its_function(f1)
# Out:
# MSE = 11233.166666666666

# %%
print_points_its_function(f1.subs(x, x-7.5))
# this mse less then 110
# Out:
# MSE = 103.16666666666667

# %% [markdown]
# ### Need to get value less 150

# %%
from sympy import *
from sympy.plotting import plot
import numpy as np
import matplotlib.pyplot as plt
init_printing(use_unicode=False, wrap_line=False, no_global=True)

# %%
def print_points_its_function(sympy_function):
    def function(x_): return float(sympy_function.subs(x, x_))
    
    x_points = np.array([-3, -2, -1, 1, 2, 3])
    y_points = np.array([-55, -40, 7, 5, 38, 53])
    plt.xlim(-5, 25)
    plt.ylim(-70, 70)
    
    plt.scatter(x_points, y_points, c='r')
    x_range = np.linspace(plt.xlim()[0], plt.xlim()[1], num=100)
    function_y = [function(x_) for x_ in x_range]
    plt.plot(x_range, function_y, 'b')
    plt.show
    
    MSE = sum([(y_points[i] - function(x_points[i]))**2 for i in range(len(y_points))]) / len(y_points)
    print(f'MSE = {MSE}')

# %%
f2 = 2 * x**3 - 121 * x**2 + 2443 * x - 16455
f2
# Out:
#    3        2
# 2*x  - 121*x  + 2443*x - 16455

# %%
print_points_its_function(f2)
# Out:
# MSE = 317653781.0

# %%
# fount value when less then 150
print_points_its_function(f2.subs(x, x+20))
# Out:
# MSE = 141.0

# %% [markdown]
# ### homework 4.4
#
# ### 1) Need to get value less then 50

# %%
from sympy import *
from sympy.plotting import plot
import numpy as np
import matplotlib.pyplot as plt
init_printing(use_unicode=False, wrap_line=False, no_global=True)

# %%
def print_points_its_fuction(sympy_function):
    def function(x_): return float(sympy_function.subs(x, x_))
    
    x_points = np.array([-2, -1, 0, 1, 2, 3, 3.5, 4, 4.5, 5])
    y_points = np.array([-15, -1, 4, -9, -2, -5, -8, 4, 13, 21])
    plt.xlim(-3, 6)
    plt.ylim(-20, 20)
    
    plt.scatter(x_points, y_points, c='r')
    x_range = np.linspace(plt.xlim()[0], plt.xlim()[1], num=100)
    Y_function = [function(x_) for x_ in x_range]
    plt.plot(x_range, Y_function, 'b')
    plt.show()
    
    MSE = sum([(y_points[i] - function(x_points[i]))**2 for i in range(len(y_points))]) / len(y_points)
    print(f'MSE = {MSE}')

# %%
f1 = 3.375 * x ** 3 - 9 * x**2
f1
# Out:
#        3      2
# 3.375*x  - 9*x

# %%
print_points_its_fuction(f1)
# Out:
# MSE = 5270.741845703125

# %%
# find function with help to unclench or clench
print_points_its_fuction(f1.subs(x, x/1.5))
# Out:
# MSE = 24.478125000000002

# %% [markdown]
# ### Need to find value less then 150

# %%
from sympy import *
from sympy.plotting import plot
import numpy as np
import matplotlib.pyplot as plt
init_printing(use_unicode=False, wrap_line=False, no_global=True)

# %%
def print_points_its_function(sympy_function):
    def function(x_): return float(sympy_function.subs(x, x_))
    points_X = np.array([-3, -2, -1, 1, 2, 3])
    points_Y = np.array([-55, -40, 7, 5, 38, 53])
    plt.xlim(-10, 10)
    plt.ylim(-70, 70)
    
    plt.scatter(points_X, points_Y, c='r')
    x_range = np.linspace(plt.xlim()[0], plt.xlim()[1], num=100)
    function_Y = [function(x_) for x_ in x_range]
    plt.plot(x_range, function_Y, 'b')
    plt.show()
    
    # find MSE
    MSE = sum([(points_Y[i] - function(points_X[i]))**2 for i in range(len(points_Y))]) / len(points_Y)
    print(f'MSE = {MSE}')

# %%
f2 = 0.074 * x**3 - 0.11 * x**2 + x + 5
f2
# Out:
#        3         2
# 0.074*x  - 0.11*x  + x + 5

# %%
print_points_its_function(f2)
# Out:
# MSE = 1262.7619146666668

# %%
print_points_its_function(f2.subs(x, x*2.9))
# Out:
# MSE = 136.9033216606747
