# %% [markdown]
# # The modul 10 of the Math - Matrix in the form of the equation

# %% [markdown]
# ## The lesson 4

# %%
import numpy as np
from sympy import *
init_printing(use_unicode=False, wrap_line=False, no_global=True)

# %%
X = Matrix([[4.1, 3.9], [4.7, 4.2]])
X
# Out:
# [4.1  3.9]
# [        ]
# [4.7  4.2]

# %%
X_augmented = Matrix([[4.1, 3.9, 4.0], [4.7, 4.2, 4.3]])
X_augmented
# Out:
# [4.1  3.9  4.0]
# [             ]
# [4.7  4.2  4.3]

# %%
# create the vector of the weight
a1, a2 = symbols('a1, a2')

# %%
#for decision the line system of the equations
linsolve(X_augmented, [a1, a2])
# Out:
# {(-0.0270270270270284, 1.05405405405406)}

# %%
a = Matrix([a1, a2])
a
# Out:
# [a1]
# [  ]
# [a2]

# %%
X*a
# Out:
# [2*a1 + 5*a2]
# [           ]
# [7*a1 - 3*a2]

# %%
b = Matrix([4.0, 4.3])
b
# Out:
# [4.0]
# [   ]
# [4.3]

# %%
# Will be to multiply matrix by vector weight and minus vector answers
C = X * a - b
C
# Out:
# [2*a1 + 5*a2 - 4.0]
# [                 ]
# [7*a1 - 3*a2 - 4.3]

# %%
# decide to find the system line of the equations 
linsolve(C, [a1, a2])
# Out:
# {(0.817073170731707, 0.473170731707317)}

# %%
X = Matrix([[2, 5], [7, -3]])
X
# Out:
# [2  5 ]
# [     ]
# [7  -3]

# %%
y = Matrix([2, 3])
y
# Out:
# [2]
# [ ]
# [3]

# %%
X * y
# Out:
# [19]
# [  ]
# [5 ]

# %% [markdown]
# ## homework of the lesson 4
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### exercise 1
# ![image.png](attachment:image.png)

# %%
# manually solve the following system of equation:
x, y = symbols('x, y')

X = Matrix([[2, 5], [7, -3]])
a = Matrix([x, y])
b = Matrix([11, -23])

# %%
equation_matrix_1 = X * a - b
equation_matrix_1
# Out:
# [2*x + 5*y - 11]
# [              ]
# [7*x - 3*y + 23]

# %%
# solve the line system of equations
linsolve(equation_matrix_1, [x, y])
# correctly
# Out:
# {(-2, 3)}

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#manually solve the following line system of the equation:
X = Matrix([[-3, 1], [3, 5]])
a = Matrix([x, y])
b = Matrix([-2, 8])

# %%
# create the line system from our equations
equation_matrix_2 = X * a - b
equation_matrix_2
# Out:
# [-3*x + y + 2 ]
# [             ]
# [3*x + 5*y - 8]

# %%
# solve out line system of the equations with help method linsolve
linsolve(equation_matrix_2, [x, y])
# it is correct answer
# Out:
# {(1, 1)}

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#solve manually the following system of the equation:
X = Matrix([[2, 3], [3, -1]])
a = Matrix([x, y])
b = Matrix([12, 7])

# %%
# create the eqaution consists of the Matrix x multiply vector weight and subract vector answers
equation_matrix_3 = X*a-b
equation_matrix_3
# Out:
# [2*x + 3*y - 12]
# [              ]
# [ 3*x - y - 7  ]

# %%
# solve the line system of the equations
linsolve(equation_matrix_3, [x, y])
# Out:
# {(3, 2)}

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# solve matually the following system of the line equation:
X = Matrix([[1, 1, 2], [2, -1, 2], [4, 1, 4]])
# create vector weight
x, y, z = symbols('x, y, z')
a = Matrix([x, y, z])
b = Matrix([-1, -4, -2])

# %%
# create a equations for function linsolve consists of the Matrix multiply the vector of the weight and subtract the vector of the answers
equation_matrix_4 = X * a - b
equation_matrix_4
# Out:
# [ x + y + 2*z + 1 ]
# [                 ]
# [2*x - y + 2*z + 4]
# [                 ]
# [4*x + y + 4*z + 2]

# %%
# use function linsolve for solve the matrix of line equations: 
linsolve(equation_matrix_4, [x, y, z])
# Out:
# {(1, 2, -2)}

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# write down SLAE in the form of the matrix equation
X = Matrix([[2, 5], [7, -3]])
a = Matrix([x, y])
b = Matrix([11, -23])

# %%
# create matrix equation
equation_matrix_5 = X * a - b
equation_matrix_5
# Out:
# [2*x + 5*y - 11]
# [              ]
# [7*x - 3*y + 23]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# write down SLAE in the from of the the matrix equation
X = Matrix([[-3, 1],[3, 5]])
a = Matrix([x, y])
b = Matrix([-2, 8])

# %%
# write down the matrix equation in the form of the line equation
equation_matrix_6 = X * a - b
equation_matrix_6
# Out:
# [-3*x + y + 2 ]
# [             ]
# [3*x + 5*y - 8]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# write down line eqution with help to sympy
X = Matrix([[2, 3], [3, -1]])
a,b = symbols('a, b')
a = Matrix([a, b])
b = Matrix([12, 7])

# %%
# write down line equation with help to equation matrix
equation_matrix_7 = X * a - b
equation_matrix_7
# Out:
# [2*a + 3*b - 12]
# [              ]
# [ 3*a - b - 7  ]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# write down the line equation with help to the matrix equations
A = Matrix([[1, 1, 2], [2, -1, 2], [4, 1, 4]])
x1, x2, x3 = symbols('x1, x2, x3')
a = Matrix([x1, x2, x3])
b = Matrix([-1, -4, -2])

# %%
# write down the line equation
equation_matrix_8 = A * a - b
equation_matrix_8
# Out:
# [ x1 + x2 + 2*x3 + 1 ]
# [                    ]
# [2*x1 - x2 + 2*x3 + 4]
# [                    ]
# [4*x1 + x2 + 4*x3 + 2]

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
# multiply matrix by vector
Matrix([[2, 5], [7, -3]]) * Matrix([2, 3])
# Out:
# [19]
# [  ]
# [5 ]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# multiply matrix be vector
Matrix([[-3, 1], [3, 5]]) * Matrix([1, 3])
# Out:
# [0 ]
# [  ]
# [18]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
Matrix([[2, 3], [3, -1]]) * Matrix([4, 2])
# Out:
# [14]
# [  ]
# [10]

# %%
Matrix([[1, 1, 2], [2, -1, 2], [4, 1, 4]]) * Matrix([2, 3, 5])
# Out:
# [15]
# [  ]
# [11]
# [  ]
# [31]

# %% [markdown]
# # The lesson 5

# %%
MSE = 1/4 * (
(4.1*a1 + 3.9*a2 - 4)**2 + \
(4.7*a1 + 4.2*a2 - 4.3)**2 + \
(3.1*a1 + 2.9*a2 - 3)**2 + \
(4.9*a1 + 5.0*a2 - 4.9)**2
)
MSE
# Out:
#                           2                                                         2                                                         2                                                         2
# 6.25*(0.98*a1 + a2 - 0.98)  + 5.5225*(a1 + 0.893617021276596*a2 - 0.914893617021276)  + 2.4025*(a1 + 0.935483870967742*a2 - 0.967741935483871)  + 4.2025*(a1 + 0.951219512195122*a2 - 0.975609756097561)

# %%
MSEa1 = diff(MSE, a1)
MSEa1
# Out:
# 36.26*a1 + 34.61*a2 - 34.96

# %%
MSEa2 = diff(MSE, a2)
MSEa2
# Out:
# 34.61*a1 + 33.13*a2 - 33.43

# %%
MSE.subs({a1: 0, a2: 0})
# Out:
# 16.8750000000000

# %%
import numpy as np
import matplotlib.pyplot as plt

def find_gradient_n(coeff, type_gradient='P', step=1/100):
    gradient = np.array([MSEa1.subs({a1: coeff[0], a2: coeff[1]}),
                           MSEa2.subs({a1: coeff[0], a2: coeff[1]})]) * step
    if type_gradient == 'P':
        return coeff + gradient
    elif type_gradient == 'N':
        return coeff + -gradient
    else:
        raise Exception('Not fount type gradient. Function get variable type gradient such as the P or N')
        

fig, ax = plt.subplots()
ax.axhline(0, color='black')
ax.axvline(0, color='black')
# min loss
# ax.scatter([coefficients_min_loss[0]], [coefficients_min_loss[1]], c='r')
# ax.annotate('min_loss \n MSE: 6.2', (coefficients_min_loss[0], coefficients_min_loss[1]))

last_gr = np.array([0, 0])
for i in range(10):
    print(f'Do iteration for searching is {i+1} anti gradient')
    gr = find_gradient_n((last_gr), 'N', 1/100)
    ax.scatter(gr[0], gr[1], c='r')
    mse_gr = MSE.subs({a1:gr[0], a2:gr[1]})
    print(f'gr: {gr}')
    print(f'MSE {i+1}: {mse_gr}')
    ax.annotate(f'gr{i+1}: {format(mse_gr, ".3f")}', (gr[0], gr[1]))
    last_gr = gr
    if mse_gr < 0.00001:
        break
# Out:
# Do iteration for searching is 1 anti gradient
# gr: [0.349600000000000 0.334300000000000]
# MSE 1: 1.58934775845000
# Do iteration for searching is 2 anti gradient
# gr: [0.456733810000000 0.436849850000000]
# MSE 2: 0.152475176254023
# Do iteration for searching is 3 anti gradient
# gr: [0.489528397409000 0.468345923054000]
# MSE 3: 0.0174061778356472
# Do iteration for searching is 4 anti gradient
# gr: [0.499530876539507 0.478057140402955]
# MSE 4: 0.00470843709035236
# Do iteration for searching is 5 anti gradient
# gr: [0.502545404412819 0.481089173417132]
# MSE 5: 0.00351375729142458
# Do iteration for searching is 6 anti gradient
# gr: [0.503417477853061 0.482073365796760]
# MSE 6: 0.00340038148468236
# Do iteration for searching is 7 anti gradient
# gr: [0.503632708481283 0.482429670623349]
# MSE 7: 0.00338865074786379
# Do iteration for searching is 8 anti gradient
# gr: [0.503646579383229 0.482593440340461]
# MSE 8: 0.00338647584705398
# ...
