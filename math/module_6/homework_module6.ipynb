# %% [markdown]
# # The homework of math module 6

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### find derivation 1

# %%
from sympy import *
init_printing(use_unicode=False, wrap_line=False, no_global=True)

# %%
x = Symbol('x')

# %%
f1 = 6**x + 3*x**3 + 5
f1
# Out:
#  x      3
# 6  + 3*x  + 5

# %%
derivation1 = diff(f1)
derivation1
# Out:
#  x             2
# 6 *log(6) + 9*x

# %% [markdown]
# ### find deribation 2

# %%
f2 = 5*x*exp(x)
f2
# Out:
#      x
# 5*x*e

# %%
derivarion2 = diff(f2)
derivarion2
# Out:
#      x      x
# 5*x*e  + 5*e

# %% [markdown]
# ### find derivation 3

# %%
f3 = pi**x + 2*sin(x)
f3
# Out:
#   x
# pi  + 2*sin(x)

# %%
derivation3 = diff(f3)
derivation3
# Out:
#   x
# pi *log(pi) + 2*cos(x)

# %% [markdown]
# ### find derivation 4

# %%
f4 = x**2/sin(x)
f4
# Out:
#    2
#   x
# ------
# sin(x)

# %%
derivation4 = diff(f4)
derivation4
# Out:
#    2
#   x *cos(x)    2*x
# - --------- + ------
#       2       sin(x)
#    sin (x)

# %%
expand((2*x*sin(x) - x**2*cos(x))/sin(x)**2)
# Out:
#    2
#   x *cos(x)    2*x
# - --------- + ------
#       2       sin(x)
#    sin (x)

# %% [markdown]
# ### find derivation 5

# %%
f5 = exp(2*x)
f5
# Out:
#  2*x
# e

# %%
derivation5 = diff(f5)
derivation5
# Out:
#    2*x
# 2*e

# %% [markdown]
# ### find derivation 6

# %%
f6 = (5*x**3)/(exp(3*x))
f6
# Out:
#    3  -3*x
# 5*x *e

# %%
exp(3*x)
# Out:
#  3*x
# e

# %%
derivation6 = diff(f6)
derivation6
# Out:
#       3  -3*x       2  -3*x
# - 15*x *e     + 15*x *e

# %%
exp(3*x)**2
# Out:
#  6*x
# e

# %% [markdown]
# ### find derivation 7

# %%
f7 = 2*(5/2 -x)**2
f7
# Out:
#                 2
# 12.5*(1 - 0.4*x)

# %%
derivation7 = diff(f7)
derivation7
# Out:
# 4.0*x - 10.0

# %% [markdown]
# ###  find derivation 8

# %%
f8 = exp(x**2)
f8
# Out:
#  / 2\
#  \x /
# e

# %%
derivation8 = diff(f8)
derivation8
# Out:
#      / 2\
#      \x /
# 2*x*e

# %% [markdown]
# ### find derivation 9

# %%
f9 = 5**(7*x**3 + 5)
f9
# Out:
#     3
#  7*x  + 5
# 5

# %%
derivation9 = diff(f9)
derivation9
# Out:
#        3
#     7*x  + 5  2
# 21*5        *x *log(5)

# %% [markdown]
# ### find derivation 10

# %%
f10 = sin(3*x**5 + exp(2*x))
f10
# Out:
#    /   5    2*x\
# sin\3*x  + e   /

# %%
derivation10 = diff(f10)
derivation10
# Out:
# /    4      2*x\    /   5    2*x\
# \15*x  + 2*e   /*cos\3*x  + e   /
