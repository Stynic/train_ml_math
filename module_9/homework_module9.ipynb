# %% [markdown]
# # Module 8 homework - find private derivation for function with several variables

# %% [markdown]
# ## exercise 1:
#
# ![image.png](attachment:image.png)

# %%
from sympy import *
from sympy.plotting import plot3d
init_printing(use_unicode=False, wrap_line=False, no_global=True)

# %%
x, y = symbols('x, y')
f = x*(y -5)**2
f
# Out:
#          2
# x*(y - 5)

# %%
plot3d(f)

# %%
private_diff_a_x = diff(private_diff_a, x)
private_diff_a_x
# Out:
#        2
# (y - 5)

# %%
private_diff_a_y = diff(private_diff_a, y)
private_diff_a_y
# Out:
# x*(2*y - 10)

# %%
plot(private_diff_a_x)

# %%
plot3d(private_diff_a_y)

# %%
solve(private_diff_a_x)
# Out:
# [5]

# %%
solve(private_diff_a_y)
# Out:
# [{x: 0}, {y: 5}]

# %%
private_diff_a.subs({x:5 , y:5})
# Out:
# 0

# %% [markdown]
# ## exercise 2:

# %%
f_2 = (y - exp(1)/20)**2 * sin(pi*x)
f_2
# Out:
#         2
# /    e \
# |y - --| *sin(pi*x)
# \    20/

# %%
differentiation_f_2_x = diff(f_2, x)
differentiation_f_2_x
# Out:
#            2
#    /    e \
# pi*|y - --| *cos(pi*x)
#    \    20/

# %%
differentiation_f_2_y = diff(f_2, y)
differentiation_f_2_y
# Out:
# /      e \
# |2*y - --|*sin(pi*x)
# \      10/

# %%
diff(sin(pi*x))
# Out:
# pi*cos(pi*x)

# %%
diff(pi)
# Out:
# 0

# %%
plot3d(f_2)

# %%
solve(differentiation_f_2_x)
# Out:
#                          e
# [{x: 1/2}, {x: 3/2}, {y: --}]
#                          20

# %%
solve(differentiation_f_2_y)
# Out:
#                      e
# [{x: 0}, {x: 1}, {y: --}]
#                      20

# %%
f_2.subs({x:exp(1)/20 , y:exp(1)/20})
# Out:
# 0

# %%
f_2.subs({x:33 , y:exp(1)/20})
# Out:
# 0

# %% [markdown]
# ##  exercise 3

# %%
f_3 = x * sin(x) * sin(y-2)
f_3
# Out:
# x*sin(x)*sin(y - 2)

# %%
differentiation_f_3_x = diff(f_3, x)
differentiation_f_3_x
# Out:
# x*sin(y - 2)*cos(x) + sin(x)*sin(y - 2)

# %%
differentiation_f_3_y = diff(f_3, y)
differentiation_f_3_y
# Out:
# x*sin(x)*cos(y - 2)

# %%
plot3d(f_3)

# %%
solve(differentiation_f_3_x)
# Out:
# [{y: 2}, {y: 2 + pi}]

# %%
solve(differentiation_f_3_y)
# Out:
#                           3*pi       pi
# [{x: 0}, {x: pi}, {y: 2 + ----}, {y: -- + 2}]
#                            2         2

# %%
f_3.subs({x:0, y:5.15})
# Out:
# 0

# %%
plot(2+3*pi/2)

# %%
plot(pi/2 + 2)

# %%
plot(2+pi)

# %%
3140*5.2
# Out:
# 16328.0

# %%
16729+14651+16328
# Out:
# 47708

# %%
a2, a1, a0 = symbols('a2, a1, a0')
MSE = 1/3 * (
    ((1945*a2 + 560*a1 + a0) - 4.3)**2 +
    ((1495*a2 + 340*a1 + a0) - 4.9)**2 +
    ((1570*a2 + 343*a1 + a0) - 5.2)**2
)
MSE
# Out:
#                                                            2                                                              2                                                             2
#                  / a0    112*a1                           \                     / a0    343*a1                           \                     / a0    68*a1                           \
# 1261008.33333333*|---- + ------ + a2 - 0.00221079691516709|  + 821633.333333333*|---- + ------ + a2 - 0.00331210191082803|  + 745008.333333333*|---- + ----- + a2 - 0.00327759197324415|
#                  \1945    389                             /                     \1570    1570                            /                     \1495    299                            /

# %%
diff(MSE, a2)
# Out:
# 3340.0*a0 + 1424006.66666667*a1 + 5655300.0*a2 - 15902.0

# %%
f_1 = ((1570*a2 + 343*a1 + a0) - 5.2)**2
f_1
# Out:
#                                                   2
#         / a0    343*a1                           \
# 2464900*|---- + ------ + a2 - 0.00331210191082803|
#         \1570    1570                            /

# %%
mse_differentiation_a2 = diff(MSE, a2)
mse_differentiation_a2
# Out:
# 3340.0*a0 + 1424006.66666667*a1 + 5655300.0*a2 - 15902.0

# %%
mse_differentiation_a1 = diff(MSE, a1)
mse_differentiation_a1
# Out:
# 828.666666666667*a0 + 364566.0*a1 + 1424006.66666667*a2 - 3905.06666666667

# %%
mse_differentiation_a0 = diff(MSE, a0)
mse_differentiation_a0
# Out:
# 2.0*a0 + 828.666666666667*a1 + 3340.0*a2 - 9.6

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
coefficients_f1 = nonlinsolve([mse_differentiation_a2,
            mse_differentiation_a1,
            mse_differentiation_a0], [a2, a1, a0]).args[0]
coefficients_f1
# Out:
# (0.00447524752475138, -0.0118811881188098, 2.24910891089204)

# %%
f = coefficients_f1[0]*x + coefficients_f1[1]*y + coefficients_f1[2]
f
# Out:
# 0.00447524752475138*x - 0.0118811881188098*y + 2.24910891089204

# %%
f_2 = 0.00447524752475138*x - 0.0118811881188098*y + 2.24910891089204
f_2
# Out:
# 0.00447524752475138*x - 0.0118811881188098*y + 2.24910891089204

# %%
plot3d(f)

# %%
f.subs({x:1520, y:431})
# Out:
# 3.93069306930713

# %%
f_2.subs({x:1520, y:431})
# Out:
# 3.93069306930711

# %% [markdown]
# ![image.png](attachment:image.png)
