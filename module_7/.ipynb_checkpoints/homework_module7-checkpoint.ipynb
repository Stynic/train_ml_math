# %%
from sympy import *
from sympy.plotting import plot
init_printing(use_unicode=False, wrap_line=False, no_global=True)

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = Symbol('x')

# %% [markdown]
# # Задание 1.
# ## 1.
# ### Получите значение MSE меньшее 0.75.

# %%
def print_points_ands_function1(sympy_function):
    def function(x_): return float(sympy_function.subs(x, x_))
    
    points_X = np.array([-2, -1, 0, 1, 2, 3, 3.5, 4, 4.5, 5])
    points_Y = np.array([3, 1, -0.5, 1.2, 2.5, 0.8, -2, -3.5, -3, -5])
    plt.xlim(-10, 10)
    plt.ylim(-5, 5)
    plt.axhline(0, color='black')
    plt.axvline(0, color='black')
    
    plt.scatter(points_X, points_Y, c='r')
    x_range = np.linspace(plt.xlim()[0], plt.xlim()[1], num=100)
    function_Y = [function(x_) for x_ in x_range]
    plt.plot(x_range, function_Y, 'b')
    plt.show()
    
    MSE = sum([(points_Y[i] - function(points_X[i]))**2 for i in range(len(points_Y))]) / len(points_Y)
    print(f'MSE = {MSE}')

# %%
b = Symbol('b')
f1_k = 1/2*x + b
f1_k

points_X = np.array([2, 1, 3])
points_Y = np.array([1, 3, 4])


MSE_f1 =        (
                (points_Y[0] - f1_k.subs(x, points_X[0]))**2 +
                (points_Y[1] - f1_k.subs(x, points_X[1]))**2 +
                (points_Y[2] - f1_k.subs(x, points_X[2]))**2 
#                 (points_Y[3] - f1_k.subs(x, points_X[3]))**2 +
#                 (points_Y[4] - f1_k.subs(x, points_X[4]))**2 +
#                 (points_Y[5] - f1_k.subs(x, points_X[5]))**2 +
#                 (points_Y[6] - f1_k.subs(x, points_X[6]))**2 +   
#                 (points_Y[7] - f1_k.subs(x, points_X[7]))**2 +
#                 (points_Y[8] - f1_k.subs(x, points_X[8]))**2 +
#                 (points_Y[9] - f1_k.subs(x, points_Y[9]))**2
                ) / len(points_Y)
MSE_f1
# Out:
#  2
# b                                2
# -- + 4.16666666666667*(1 - 0.4*b)
# 3

# %%
diff(MSE_f1)
# Out:
# 2.0*b - 3.33333333333333

# %%
f1 = 2 * x * sin(2 * x + 5) + 5 * sin(2 * x + 5) + 2
f1
# Out:
# 2*x*sin(2*x + 5) + 5*sin(2*x + 5) + 2

# %%
print_points_ands_function1(f1.subs(x, x-1.2)-1.4)
# Out:
# MSE = 17.59285988461223

# %%
a, b, c = symbols('a, b, c')
f1_abc = (2 * x * sin(2 * x + 5))*a + (5 * sin(2 * x + 5)) + 2
f1_abc

range_equation = [(2 * x * sin(2 * x + 5)) , (5 * sin(2 * x + 5)), 2]
range_equation
# Out:
# [2*x*sin(2*x + 5), 5*sin(2*x + 5), 2]

# %%
range_variable = [a, b, c]
range_variable
# Out:
# [a, b, c]

# %%
def find_MSE(dict_func, mse=1.25):
    points_X = np.array([-2, -1, 0, 1, 2, 3, 3.5, 4, 4.5, 5])
    points_Y = np.array([3, 1, -0.5, 1.2, 2.5, 0.8, -2, -3.5, -3, -5])
#     for key, variable in range
#     f1_abc = 

    MSE_f1 =        (
                (points_Y[0] - f1_abc.subs(x, points_X[0]))**2 +
                (points_Y[1] - f1_abc.subs(x, points_X[1]))**2 +
                (points_Y[2] - f1_abc.subs(x, points_X[2]))**2 +
                (points_Y[3] - f1_abc.subs(x, points_X[3]))**2 +
                (points_Y[4] - f1_abc.subs(x, points_X[4]))**2 +
                (points_Y[5] - f1_abc.subs(x, points_X[5]))**2 +
                (points_Y[6] - f1_abc.subs(x, points_X[6]))**2 +   
                (points_Y[7] - f1_abc.subs(x, points_X[7]))**2 +
                (points_Y[8] - f1_abc.subs(x, points_X[8]))**2 +
                (points_Y[9] - f1_abc.subs(x, points_Y[9]))**2
                ) / len(points_Y)
    print(f'MSE from formule {f1_abc} result :{MSE_f1}\n')
    diff_mes = diff(MSE_f1)
    print(f'MSE` result :{diff_mes}\n')
    null_diff = solve(diff_mes)[0]
    print(f'MSE` null result :{null_diff}\n')

    print_points_ands_function1(dict_func)

# %% [markdown]
# ## 2.
# ### Получите значение MSE меньшее 0.1.

# %%
def print_points_ands_function2(sympy_function):
    def function(x_): return float(sympy_function.subs(x, x_))
    
    points_X = np.array([0, 1, 2, 3, 3.5, 4, 4.5, 5, 6, 6.5, 7, 8, 9])
    points_Y = np.array([0.5, 1.2, 0.7, 1.2, 1.1, 0.7, 0.65, 0.9, 0.95, 0.3, 0.8, 0.5, 0.0])
    plt.xlim(-1, 20)
    plt.ylim(-2, 2)
    plt.axhline(0, color='black')
    plt.axvline(0, color='black')
    
    
    plt.scatter(points_X, points_Y, c='r')
    x_range = np.linspace(plt.xlim()[0] + 1, plt.xlim()[1], num=100)
    function_Y = [function(x_) for x_ in x_range]
    plt.plot(x_range, function_Y, 'b')
    plt.show()
    
    MSE = sum([(points_Y[i] - function(points_X[i]))**2 for i in range(len(points_Y))]) / len(points_Y)
    print(f'MSE = {MSE}')

# %%
f2 = (sin(sqrt(3))/a *sqrt(x)) - 1
f2
# Out:
#        ___    /  ___\
#      \/ x *sin\\/ 3 /
# -1 + ----------------
#             a

# %%
def find_MSE(dict_func, mse=1.25):
    points_X = np.array([0, 1, 2, 3, 3.5, 4, 4.5, 5, 6, 6.5, 7, 8, 9])
    points_Y = np.array([0.5, 1.2, 0.7, 1.2, 1.1, 0.7, 0.65, 0.9, 0.95, 0.3, 0.8, 0.5, 0.0])
#     for key, variable in range
#     f1_abc = 

    MSE_f1 =        (
                (points_Y[0] - f1_abc.subs(x, points_X[0]))**2 +
                (points_Y[1] - f1_abc.subs(x, points_X[1]))**2 +
                (points_Y[2] - f1_abc.subs(x, points_X[2]))**2 +
                (points_Y[3] - f1_abc.subs(x, points_X[3]))**2 +
                (points_Y[4] - f1_abc.subs(x, points_X[4]))**2 +
                (points_Y[5] - f1_abc.subs(x, points_X[5]))**2 +
                (points_Y[6] - f1_abc.subs(x, points_X[6]))**2 +   
                (points_Y[7] - f1_abc.subs(x, points_X[7]))**2 +
                (points_Y[8] - f1_abc.subs(x, points_X[8]))**2 +
                (points_Y[9] - f1_abc.subs(x, points_Y[9]))**2 +
        (points_Y[10] - f1_abc.subs(x, points_Y[10]))**2 +
        (points_Y[11] - f1_abc.subs(x, points_Y[11]))**2+
        (points_Y[12] - f1_abc.subs(x, points_Y[12]))**2
                ) / len(points_Y)
    print(f'MSE from formule {f1_abc} result :{MSE_f1}\n')
    diff_mes = diff(MSE_f1)
    print(f'MSE` result :{diff_mes}\n')
    null_diff = solve(diff_mes)[0]
    print(f'MSE` null result :{null_diff}\n')

    print_points_ands_function2((sin(sqrt(3))/null_diff *sqrt(x)) - 1)
    return (sin(sqrt(3))/null_diff *sqrt(x)) - 1

# %%
find_MSE(f2)
# Out:
# MSE from formule 2*a*x*sin(2*x + 5) + 5*sin(2*x + 5) + 2 result :6.11427212197688*(-a - 0.706977810940265)**2 + 3.25287903889391*(-a - 0.669155861769494)**2 + 0.889667688433717*(-0.988385532558484*a - 1)**2 + 0.868737035007064*(-0.490530755265295*a - 1)**2 + 1.28359058170403*(-0.321663341723884*a - 1)**2 + 0.584995914742685*(-0.180753870732785*a - 1)**2 + 0.163146642956627*(0.260077834859634*a + 1)**2 + 0.00600561697182723*(a - 0.368349320881609)**2 + 10.2382353680378*(a + 0.325653323341904)**2 + 1.0852011015572*(a + 0.474669765999401)**2 + 2.76917652885411*(a + 0.699998694193972)**2 + (-2 - 5*sin(5))**2/13 + (-1.5 - 5*sin(5))**2/13
#
# MSE` result :49.4137705128678*a + 28.302610310441
#
# MSE` null result :-0.572767672183015
# MSE = 28.258003794583374
#                      ___    /  ___\
# - 1.74590859185306*\/ x *sin\\/ 3 / - 1

# %%
points_Y = np.array([0.5, 1.2, 0.7, 1.2, 1.1, 0.7, 0.65, 0.9, 0.95, 0.3, 0.8, 0.5, 0.0])
len(points_Y)
# Out:
# 13

# %%
print_points_ands_function2(f2/2.1 +1.4)
# Out:
# MSE = 0.09916817988329256

# %% [markdown]
# # Задание 2.
#
# Постройте графики функций 2 переменных. Найдите их нули и затем постройте графики их нулей, если они не представляют собой выражения вида {x: ...}. <br>
# а) $f(x,y)=xy^2$.
# б) $f(x,y)=y^2sin(\pi x)$.
# в)$f(x,y)=x sin(x) sin(y)$.

# %% [markdown]
# ### exercise 1
#
# а) $f(x,y)=xy^2$.

# %%
from sympy import *
from sympy.plotting import plot3d
init_printing(use_unicode=False, wrap_line=False, no_global=True)

x,y = symbols('x,y')
f = x*y**2
f
# Out:
#    2
# x*y

# %%
#find zero points for function with two coefficients
solve(f)
# Out:
# [{x: 0}, {y: 0}]

# %%
# check zepo points
f.subs(x, 0), f.subs(y, 0)
# Out:
# (0, 0)

# %%
plot3d(f)

# %% [markdown]
# ### exercise 2
#
# $f(x,y)=y^2sin(\pi x)$.

# %%
from sympy import *
from sympy.plotting import plot3d
init_printing(use_unicode=False, wrap_line=False, no_global=True)

# %%
f2 = y**2*sin(pi*x)
f2
# Out:
#  2
# y *sin(pi*x)

# %%
# find zero points for function with two coefficients
solve(f2)
# Out:
# [{x: 0}, {x: 1}, {y: 0}]

# %%
# check zero points
f2.subs(x, 0), f2.subs(x, 1), f2.subs(y, 0)
# Out:
# (0, 0, 0)

# %%
plot3d(f2)

# %% [markdown]
# ### exercise 3
#
# $f(x,y)=x sin(x) sin(y)$.

# %%
f3 = x*sin(x)*sin(y)
f3
# Out:
# x*sin(x)*sin(y)

# %%
#find zero points for function with two coefficients
solve(f3)
# Out:
# [{x: 0}, {x: pi}, {y: 0}, {y: pi}]

# %%
# check zero points
f3.subs(x, 0), f3.subs(x, pi), f3.subs(y, 0), f3.subs(y, pi)
# Out:
# (0, 0, 0, 0)

# %%
plot3d(f3)

# %%
f4 = (y - exp(1) /20)**2 * sin(pi * x)
f4
# Out:
#         2
# /    e \
# |y - --| *sin(pi*x)
# \    20/

# %%
solve(f4)
# Out:
#                      e
# [{x: 0}, {x: 1}, {y: --}]
#                      20

# %%
plot(exp(1)/ 20)

# %%
f4.subs(x, 0), f4.subs(x, 1), f4.subs(y, exp(1)/20)
# Out:
# (0, 0, 0)

# %%
plot3d(f4)

# %% [markdown]
# # Задание 3.
#
#
# ## а)
#
# Дана функция:
# $$f(x_1,x_2,x_3,x_4)=a_4x_4+a_3x_3+a_2x_2+a_1x_1+a_0$$
# Данная функция отвечает на вопрос: “является ли текст спамом или нет?”. Если является, функция возвращает 1, если нет – 0. Переменная $x_1$ равна количеству раз, которое в тексте встретилось в одной из своих форм слово “покупать”. Переменная $x_2$ равна 1, если в тексте есть слово “скидка” и 0 в противном случае. Переменная $x_3$ равна 1, если в тексте есть слово “акция” и 0 в противном случае. $x_4$ равна длине текста в словах.
#
# ### 1. Запишите функцию в виде:
# ``` название функции: область определения → область значений ```
#
# **Ответ:**

# %%
#f(x1, x2, x3, x4): [0;+inf) x {0, 1} x {0, 1} x [0; +inf) => {0, 1}
# Out:
#   File "/tmp/ipykernel_9359/3838122183.py", line 1
#     f(x1, x2, x3, x4): [0;+inf) x {0, 1} x {0, 1} x [0; +inf) => {0, 1}
#                          ^
# SyntaxError: invalid syntax

# %%
f.subs?

# %% [markdown]
# ### 2. Какую размерность будет иметь задаваемая этой функцией гиперплоскость?
#
# **Ответ:** 4

# %% [markdown]
# ## б)
#
# Дана функция:
# $$f(x_1,x_2,x_3)=a_3x_3+a_2x_2+a_1x_1+a_0$$
# Данная функция отвечает на вопрос: “с какой вероятностью клиент сделает вклад?”. Переменная $x_1$ равна количеству раз, которое клиент делал вклады ранее. Переменная $x_2$ равна сумме всех этих вкладов. Переменная $x_3$ равна 1, если у клиента есть вклад в данный момент, и 0 в противном случае.
#
# ### 1. Запишите функцию в виде:
# ``` название функции: область определения → область значений ```
#
# **Ответ:**

# %%
#f(x1, x2, x3): [0; +inf) x [0; + inf) x {0, 1} ==> {0, 1}

# %% [markdown]
# ### 2. Какую размерность будет иметь задаваемая этой функцией гиперплоскость?
#
# **Ответ:** 3

# %% [markdown]
# ## в)
#
# Дана функция:
# $$f(x_1,x_2,x_3,x_4)=a_4x_4+a_3x_3+a_2x_2+a_1x_1+a_0$$
#
# Данная функция отвечает на вопрос: “болен ли пациент гриппом?”. Переменная $x_1$ равна 1, если пациент привит от гриппа, и 0 в противном случае. Переменная $x_2$ равна температуре пациента. Переменная $x_3$ равна 1, если у пациента есть кашель, и 0 в противном случае. $x_4$ равна 1, если у пациента есть насморк, и 0 в противном случае.
#
# ### 1. Запишите функцию в виде:
# ``` название функции: область определения → область значений ```
#
# **Ответ:**

# %%
#f(x1, x2, x3, x4): {0, 1} x [34.0; 41] x {0, 1} x {0, 1}  => {0, 1}

# %% [markdown]
# ### 2. Какую размерность будет иметь задаваемая этой функцией гиперплоскость?
#
# **Ответ:** 4
