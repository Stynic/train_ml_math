# %% [markdown]
# ## Notebook for work with pandas by course demo analysis by Karpov courses

# %% [markdown]
# ## read files and data

# %%
import pandas as pd

# %%
df = pd.read_csv('lesson_1_data.csv', sep=';', encoding='windows-1251')

# %%
df.head()
# Out:
#      Номер     Дата создания       Дата оплаты                        Title  \
# 0  1062823  01.12.2019 10:50  01.12.2019 10:52      Курс обучения «Эксперт»
# 1  1062855  01.12.2019 20:53  01.12.2019 21:27      Курс обучения «Эксперт»
# 2  1062856  01.12.2019 21:43               NaN   Курс обучения «Специалист»
# 3  1062880   03.12.2019 0:18               NaN  Курс обучения «Консультант»
# 4  1062899  03.12.2019 21:43               NaN      Курс обучения «Эксперт»
#
#      Статус  Заработано                          Город   Платежная система
# 0  Завершен     29597.5                           Чита  Сбербанк эквайринг
# 1  Завершен     17450.3                      Краснодар        Яндекс.Касса
# 2   Отменен         0.0                            NaN                 NaN
# 3   Отменен         0.0  г.Москва и Московская область                 NaN
# 4   Отменен         0.0  г.Москва и Московская область                 NaN

# %%
#attributes for work with dimensional

# %%
df.shape
# Out:
# (292, 8)

# %%
df.dtypes
# Out:
# Номер                  int64
# Дата создания         object
# Дата оплаты           object
# Title                 object
# Статус                object
# Заработано           float64
# Город                 object
# Платежная система     object
# dtype: object

# %%
# method for work with disribe numerale columns
df.describe()
# Out:
#               Номер    Заработано
# count  2.920000e+02    292.000000
# mean   1.063745e+06   3397.615034
# std    4.438688e+02   5771.572829
# min    1.062823e+06      0.000000
# 25%    1.063608e+06      0.000000
# 50%    1.063698e+06   2935.440000
# 75%    1.063807e+06   2935.440000
# max    1.064796e+06  42750.000000

# %%
# method for rename index or columns

# %%
df.rename(index={0: "Ivan"},
          columns={'Дата оплаты': 'data_pay', 'Дата создания': 'data_created'})
# Out:
#         Номер      data_created          data_pay  \
# Ivan  1062823  01.12.2019 10:50  01.12.2019 10:52
# 1     1062855  01.12.2019 20:53  01.12.2019 21:27
# 2     1062856  01.12.2019 21:43               NaN
# 3     1062880   03.12.2019 0:18               NaN
# 4     1062899  03.12.2019 21:43               NaN
# ...       ...               ...               ...
# 287   1064720   30.12.2019 9:42  30.12.2019 12:49
# 288   1064724  30.12.2019 11:32               NaN
# 289   1064775   31.12.2019 2:17   31.12.2019 2:22
# 290   1064793  31.12.2019 16:40  01.01.2020 14:29
# 291   1064796  31.12.2019 17:29  31.12.2019 17:32
#
#                                                   Title    Статус  Заработано  \
# Ivan                            Курс обучения «Эксперт»  Завершен    29597.50
# 1                               Курс обучения «Эксперт»  Завершен    17450.30
# 2                            Курс обучения «Специалист»   Отменен        0.00
# ...

# %%
# communication with columns

# %%
# ways to shows columns
# first way
df['Дата оплаты']
# Out:
# 0      01.12.2019 10:52
# 1      01.12.2019 21:27
# 2                   NaN
# 3                   NaN
# 4                   NaN
#              ...
# 287    30.12.2019 12:49
# 288                 NaN
# 289     31.12.2019 2:22
# 290    01.01.2020 14:29
# 291    31.12.2019 17:32
# Name: Дата оплаты, Length: 292, dtype: object

# %%
# second way
df.Title
# Out:
# 0                                Курс обучения «Эксперт»
# 1                                Курс обучения «Эксперт»
# 2                             Курс обучения «Специалист»
# 3                            Курс обучения «Консультант»
# 4                                Курс обучения «Эксперт»
#                              ...
# 287    Подписка «ОНЛАЙН ДИЕТОЛОГ» с ежемесячным автос...
# 288                          Курс обучения «Консультант»
# 289                          Курс обучения «Консультант»
# 290    Подписка «ОНЛАЙН ДИЕТОЛОГ» с ежемесячным автос...
# 291    Курс от Школы Диетологов. Повышение квалификац...
# Name: Title, Length: 292, dtype: object

# %%
# trird way to show several columns
df[['Title', 'Статус']]
# Out:
#                                                  Title    Статус
# 0                              Курс обучения «Эксперт»  Завершен
# 1                              Курс обучения «Эксперт»  Завершен
# 2                           Курс обучения «Специалист»   Отменен
# 3                          Курс обучения «Консультант»   Отменен
# 4                              Курс обучения «Эксперт»   Отменен
# ..                                                 ...       ...
# 287  Подписка «ОНЛАЙН ДИЕТОЛОГ» с ежемесячным автос...  Завершен
# 288                        Курс обучения «Консультант»   Отменен
# 289                        Курс обучения «Консультант»  Завершен
# 290  Подписка «ОНЛАЙН ДИЕТОЛОГ» с ежемесячным автос...  Завершен
# 291  Курс от Школы Диетологов. Повышение квалификац...  Завершен
#
# [292 rows x 2 columns]

# %%
df.iloc[5:10, 3:5]
# Out:
#                          Title   Статус
# 5  Курс обучения «Консультант»  Отменен
# 6  Курс обучения «Консультант»  Отменен
# 7  Курс обучения «Консультант»  Отменен
# 8      Курс обучения «Эксперт»  Отменен
# 9      Курс обучения «Эксперт»  Отменен

# %%
df.iloc[[1, 2, 10, 100], [0, 4, -1]]
# Out:
#        Номер    Статус safe
# 1    1062855  Завершен  Yes
# 2    1062856   Отменен  Yes
# 10   1062927   Отменен  Yes
# 100  1063648  Завершен  Yes

# %%
df.loc[5:10, ['Заработано', 'Город']]
# Out:
#     Заработано                          Город
# 5          0.0             Краснодарский край
# 6          0.0                            NaN
# 7          0.0        Республика Башкортостан
# 8          0.0               Тульская область
# 9          0.0           Республика Татарстан
# 10         0.0  г.Москва и Московская область

# %%
df[0:10][['Номер', 'Title']]
# Out:
#      Номер                        Title
# 0  1062823      Курс обучения «Эксперт»
# 1  1062855      Курс обучения «Эксперт»
# 2  1062856   Курс обучения «Специалист»
# 3  1062880  Курс обучения «Консультант»
# 4  1062899      Курс обучения «Эксперт»
# 5  1062900  Курс обучения «Консультант»
# 6  1062911  Курс обучения «Консультант»
# 7  1062914  Курс обучения «Консультант»
# 8  1062915      Курс обучения «Эксперт»
# 9  1062925      Курс обучения «Эксперт»

# %%
# create a new column
df['safe'] = 'Yes'

# %%
df
# Out:
#        Номер     Дата создания       Дата оплаты  \
# 0    1062823  01.12.2019 10:50  01.12.2019 10:52
# 1    1062855  01.12.2019 20:53  01.12.2019 21:27
# 2    1062856  01.12.2019 21:43               NaN
# 3    1062880   03.12.2019 0:18               NaN
# 4    1062899  03.12.2019 21:43               NaN
# ..       ...               ...               ...
# 287  1064720   30.12.2019 9:42  30.12.2019 12:49
# 288  1064724  30.12.2019 11:32               NaN
# 289  1064775   31.12.2019 2:17   31.12.2019 2:22
# 290  1064793  31.12.2019 16:40  01.01.2020 14:29
# 291  1064796  31.12.2019 17:29  31.12.2019 17:32
#
#                                                  Title    Статус  Заработано  \
# 0                              Курс обучения «Эксперт»  Завершен    29597.50
# 1                              Курс обучения «Эксперт»  Завершен    17450.30
# 2                           Курс обучения «Специалист»   Отменен        0.00
# ...

# %%
# calculatence methods

# %%
# method aggrigation multipilication all of elements for column
df.Заработано.product()
# Out:
# 0.0

# %%
df.groupby(['Title', 'Статус']) \
  .agg({'Статус': 'count'})
# Out:
#                                                                      Статус
# Title                                              Статус
# Курс обучения «Консультант»                        Завершен              31
#                                                    Отменен               21
# Курс обучения «Специалист»                         Завершен               7
#                                                    Отменен                5
# Курс обучения «Эксперт»                            Завершен               5
#                                                    Отменен               17
# Курс от Школы Диетологов. Бизнес                   Завершен               3
#                                                    Отменен                5
#                                                    Частично оплачен       1
# Курс от Школы Диетологов. Повышение квалификации.  Завершен               9
#                                                    Отменен                5
# ...

# %%
(df.groupby(['Title', 'Статус'], as_index=True)
   .agg({'Статус': 'count'}))
# Out:
#                                                                      Статус
# Title                                              Статус
# Курс обучения «Консультант»                        Завершен              31
#                                                    Отменен               21
# Курс обучения «Специалист»                         Завершен               7
#                                                    Отменен                5
# Курс обучения «Эксперт»                            Завершен               5
#                                                    Отменен               17
# Курс от Школы Диетологов. Бизнес                   Завершен               3
#                                                    Отменен                5
#                                                    Частично оплачен       1
# Курс от Школы Диетологов. Повышение квалификации.  Завершен               9
#                                                    Отменен                5
# ...

# %%
# train with groupby and aggregation function
df.groupby(['Город', 'Title'], as_index=True).agg({'Заработано': 'sum'})
# Out:
#                                                                                               Заработано
# Город                                     Title
# Massagno                                  Курс обучения «Консультант»                            5044.05
# a.s                                       Подписка «ОНЛАЙН ДИЕТОЛОГ» с ежемесячным автосп...     2935.44
# Алматы                                    Подписка «ОНЛАЙН ДИЕТОЛОГ» с ежемесячным автосп...     2914.30
# Амурская область                          Подписка «ОНЛАЙН ДИЕТОЛОГ» с ежемесячным автосп...        0.00
# Армавир                                   Подписка «ОНЛАЙН ДИЕТОЛОГ» с ежемесячным автосп...        0.00
# ...                                                                                                  ...
# г.Санкт-Петербург и Ленинградская область Курс обучения «Консультант»                            8820.32
# ...

# %%
# create dataframe with the help of several series

# %%
name = pd.Index(data=['Vacya', 'Daniil', 'Mary'])
age = pd.Series(data=[18, 23, 14], index=name)
degree = pd.Series(data=['school', 'Bacalavar', 'school'], index=name)
data = pd.DataFrame({'age': age, 'degree': degree})

# %%
data.head()
# Out:
#         age     degree
# Vacya    18     school
# Daniil   23  Bacalavar
# Mary     14     school

# %%
df.select_dtypes(include=['int64','float'])
# Out:
#        Номер  Заработано
# 0    1062823    29597.50
# 1    1062855    17450.30
# 2    1062856        0.00
# 3    1062880        0.00
# 4    1062899        0.00
# ..       ...         ...
# 287  1064720     2935.44
# 288  1064724        0.00
# 289  1064775     7423.92
# 290  1064793     2935.44
# 291  1064796     9898.56
#
# [292 rows x 2 columns]

# %% [markdown]
# ## train in pandas with condition

# %%
df.head()
# Out:
#      Номер     Дата создания       Дата оплаты                        Title  \
# 0  1062823  01.12.2019 10:50  01.12.2019 10:52      Курс обучения «Эксперт»
# 1  1062855  01.12.2019 20:53  01.12.2019 21:27      Курс обучения «Эксперт»
# 2  1062856  01.12.2019 21:43               NaN   Курс обучения «Специалист»
# 3  1062880   03.12.2019 0:18               NaN  Курс обучения «Консультант»
# 4  1062899  03.12.2019 21:43               NaN      Курс обучения «Эксперт»
#
#      Статус  Заработано                          Город   Платежная система  \
# 0  Завершен     29597.5                           Чита  Сбербанк эквайринг
# 1  Завершен     17450.3                      Краснодар        Яндекс.Касса
# 2   Отменен         0.0                            NaN                 NaN
# 3   Отменен         0.0  г.Москва и Московская область                 NaN
# 4   Отменен         0.0  г.Москва и Московская область                 NaN
#
#   safe
# 0  Yes
# 1  Yes
# 2  Yes
# 3  Yes
# 4  Yes

# %%
# use boolean array

df[(df['Заработано'] > 10000) & (df['Город'] == 'Краснодар')]
# Out:
#       Номер     Дата создания       Дата оплаты                       Title  \
# 1   1062855  01.12.2019 20:53  01.12.2019 21:27     Курс обучения «Эксперт»
# 50  1063391   17.12.2019 9:59  17.12.2019 10:01  Курс обучения «Специалист»
#
#       Статус  Заработано      Город   Платежная система safe
# 1   Завершен     17450.3  Краснодар        Яндекс.Касса  Yes
# 50  Завершен     29695.7  Краснодар  Сбербанк эквайринг  Yes

# %% [markdown]
# ## task by stepic
# ![image.png](attachment:79aa7e41-e166-4dc5-ac5c-a9769c0a6615.png)

# %%
data_students = pd.read_csv('StudentsPerformance.csv')
data_students.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
query_free = data_students['lunch'] == 'free/reduced'
lunch_true = data_students[query_free].shape[0]
print('share:', lunch_true / data_students.shape[0])
# Out:
# share: 0.355

# %%
data_students.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
data_students.columns = ['gender', 'race/ethnicity', 'parental_level_of_education', 'lunch',
       'test_preparation_course', 'math_score', 'reading_score',
       'writing_score']

# %%
score = 90
lunch_true = data_students.query('(lunch == "free/reduced") & (math_score>@score)')
lunch_true
# Out:
#      gender race/ethnicity parental_level_of_education         lunch  \
# 149    male        group E          associate's degree  free/reduced
# 566  female        group E           bachelor's degree  free/reduced
# 689    male        group E                some college  free/reduced
# 719    male        group E          associate's degree  free/reduced
# 903  female        group D           bachelor's degree  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score
# 149               completed         100            100             93
# 566               completed          92            100            100
# 689                    none          93             90             83
# 719               completed          91             73             80
# 903               completed          93            100            100

# %%
# how to find out all markers in feature
data_students['lunch'].unique()
# Out:
# array(['standard', 'free/reduced'], dtype=object)

# %%
data_students.groupby('lunch').agg({'math_score': ['mean', 'std'],
                                    'reading_score': ['mean', 'std'],
                                    'writing_score': ['mean', 'std']})
# Out:
#              math_score            reading_score            writing_score  \
#                    mean        std          mean        std          mean
# lunch
# free/reduced  58.921127  15.159956     64.653521  14.895339     63.022535
# standard      70.034109  13.653501     71.654264  13.830602     70.823256
#
#
#                     std
# lunch
# free/reduced  15.433823
# standard      14.339487

# %%
data_students.groupby('lunch').describe()
# Out:
#              math_score                                                       \
#                   count       mean        std   min   25%   50%   75%    max
# lunch
# free/reduced      355.0  58.921127  15.159956   0.0  49.0  60.0  69.0  100.0
# standard          645.0  70.034109  13.653501  19.0  61.0  69.0  80.0  100.0
#
#              reading_score             ...              writing_score  \
#                      count       mean  ...   75%    max         count
# lunch                                  ...
# free/reduced         355.0  64.653521  ...  75.0  100.0         355.0
# standard             645.0  71.654264  ...  82.0  100.0         645.0
#
#
#                    mean        std   min   25%   50%   75%    max
# lunch
# free/reduced  63.022535  15.433823  10.0  53.0  64.0  74.0  100.0
# standard      70.823256  14.339487  22.0  62.0  72.0  81.0  100.0
#
# [2 rows x 24 columns]

# %%
# filter with str literal by word - score
data_students.filter(like='score', axis=1).head(3)
# Out:
#    math_score  reading_score  writing_score
# 0          72             72             74
# 1          69             90             88
# 2          90             95             93

# %% [markdown]
# ## practice by lesson 2 in course Analysis data

# %%
import pandas as pd

# %%
taxi = pd.read_csv('2_taxi_nyc.csv')
print(data.shape)
print(data.dtypes)
# Out:
# (29101, 14)
# pickup_dt        object
# pickup_month     object
# borough          object
# pickups           int64
# hday             object
# spd             float64
# vsb             float64
# temp            float64
# dewp            float64
# slp             float64
# pcp 01          float64
# pcp 06          float64
# pcp 24          float64
# sd              float64
# dtype: object

# %%
taxi.head()
# Out:
#              pickup_dt pickup_month    borough  pickups hday  spd   vsb  temp  \
# 0  2015-01-01 01:00:00          Jan      Bronx      152    Y  5.0  10.0  30.0
# 1  2015-01-01 01:00:00          Jan   Brooklyn     1519    Y  5.0  10.0  30.0
# 2  2015-01-01 01:00:00          Jan        EWR        0    Y  5.0  10.0  30.0
# 3  2015-01-01 01:00:00          Jan  Manhattan     5258    Y  5.0  10.0  30.0
# 4  2015-01-01 01:00:00          Jan     Queens      405    Y  5.0  10.0  30.0
#
#    dewp     slp  pcp_01  pcp_06  pcp_24   sd
# 0   7.0  1023.5     0.0     0.0     0.0  0.0
# 1   7.0  1023.5     0.0     0.0     0.0  0.0
# 2   7.0  1023.5     0.0     0.0     0.0  0.0
# 3   7.0  1023.5     0.0     0.0     0.0  0.0
# 4   7.0  1023.5     0.0     0.0     0.0  0.0

# %%
# need to rename columns without spaces(3)
columns_without_space = taxi.filter(like='pcp').columns 
obj = dict(zip(taxi.filter(like='pcp'), [column.replace(' ', '_') for column in taxi.filter(like='pcp').columns]))
taxi.rename(columns=obj, inplace=True)

# %%
# need to find out the count to seen Brooklyn in dataset
taxi['borough'].value_counts()['Brooklyn']
# Out:
# 4343

# %%
# found out borough where to completed max count of trips
(taxi
 .groupby('borough')
 .agg({'pickups': 'sum'})
 .idxmax())
# Out:
# pickups    Manhattan
# dtype: object

# %%
# found out borough where to completed min pickups
min_pickups = (taxi
 .groupby('borough')
 .agg({'pickups': 'sum'})
 .idxmin())

# %%
# need to group by holiday
(taxi
 .groupby(['borough', 'hday'], as_index=False)
 .agg({'pickups': 'mean'}))
# Out:
#           borough hday      pickups
# 0           Bronx    N    50.771073
# 1           Bronx    Y    48.065868
# 2        Brooklyn    N   534.727969
# 3        Brooklyn    Y   527.011976
# 4             EWR    N     0.023467
# 5             EWR    Y     0.041916
# 6       Manhattan    N  2401.302921
# 7       Manhattan    Y  2035.928144
# 8          Queens    N   308.899904
# 9          Queens    Y   320.730539
# 10  Staten Island    N     1.606082
# 11  Staten Island    Y     1.497006

# %%
# need to count pickups by mount
pickups_by_mon_bor = (taxi
.groupby(['borough', 'pickup_month'], as_index=False)
.agg({'pickups': 'sum'})
.sort_values('pickups', ascending=False))

# %%
# need to create function for calculation tempreture to celcius

def temp_to_celcius(data):
    return ((data - 32) * 5) / 9

taxi['temp_C'] = temp_to_celcius(taxi['temp'])
taxi['temp_C'][:5]
# Out:
# 0   -1.111111
# 1   -1.111111
# 2   -1.111111
# 3   -1.111111
# 4   -1.111111
# Name: temp_C, dtype: float64

# %% [markdown]
# ## task on filter data

# %%
import pandas as pd

heroes = pd.read_csv('dota_hero_stats.csv', index_col=0)
print(heroes.shape)
print(heroes.dtypes)
# Out:
# (117, 7)
# attack_type       object
# id                 int64
# legs               int64
# localized_name    object
# name              object
# primary_attr      object
# roles             object
# dtype: object

# %%
(heroes
.groupby('legs')
.agg({'legs': 'count'}))
# Out:
#       legs
# legs
# 0       11
# 2       95
# 4        7
# 6        3
# 8        1

# %%
(heroes
.groupby(['attack_type', 'primary_attr'])
.agg({'primary_attr': 'count'})
.idxmax())
# Out:
# primary_attr    (Ranged, int)
# dtype: object

# %%
url = 'https://stepik.org/media/attachments/course/4852/accountancy.csv'
data = pd.read_csv(url, index_col=0)
print(data.shape)
print(data.dtypes)
# Out:
# (50, 3)
# Executor    object
# Type        object
# Salary       int64
# dtype: object

# %%
data.head()
# Out:
#   Executor Type  Salary
# 0     Pupa    D      63
# 1     Pupa    A     158
# 2     Pupa    D     194
# 3     Pupa    E     109
# 4    Loopa    E     184

# %%
(data
.groupby(['Type', 'Executor'])
.agg({'Salary': 'mean'}))
# Out:
#                    Salary
# Type Executor
# A    Loopa      58.000000
#      Pupa      160.833333
# B    Loopa     145.166667
#      Pupa       77.000000
# C    Loopa     154.333333
#      Pupa       74.500000
# D    Loopa     137.714286
#      Pupa      146.500000
# E    Loopa     164.000000
#      Pupa      131.200000
# F    Loopa     238.000000
#      Pupa      136.250000

# %%
url = 'http://stepik.org/media/attachments/course/4852/algae.csv'
concentrations = pd.read_csv(url)
print(concentrations.shape)
print(concentrations.dtypes)
# Out:
# (10, 8)
# species        object
# genus          object
# group          object
# sucrose       float64
# alanin        float64
# citrate       float64
# glucose       float64
# oleic_acid    float64
# dtype: object

# %%
len(int_columns)
# Out:
# 5

# %% [markdown]
# ## task by group
# ![image.png](attachment:9fc4cb79-8868-4084-bafa-d183290d2dbd.png)

# %%
int_columns = concentrations.select_dtypes(include=['float']).columns
obj = dict(zip(int_columns, ['mean']*len(int_columns)))

mean_concentrations = (concentrations
.groupby('genus')
.agg(obj))

mean_concentrations
# Out:
#               sucrose    alanin   citrate   glucose  oleic_acid
# genus
# Ascophyllum  6.825467  0.875429  5.253527  3.414961    2.432526
# Cladophora   4.008792  3.997055  5.288311  2.800276    2.263472
# Fucus        4.355112  3.566411  4.214878  2.814803    3.367647
# Palmaria     0.704580  3.176440  5.573905  3.242090    2.245538
# Saccharina   4.183596  3.524207  3.346710  4.980594    4.487252

# %%
concentrations.head()
# Out:
#                species       genus  group   sucrose    alanin   citrate  \
# 0    Fucus_vesiculosus       Fucus  brown  3.001472  3.711498  5.004262
# 1  Saccharina_japonica  Saccharina  brown  6.731070  1.255251  5.621499
# 2       Fucus_serratus       Fucus  brown  3.276870  0.346431  1.216767
# 3      Fucus_distichus       Fucus  brown  6.786996  6.641303  6.423606
# 4    Cladophora_fracta  Cladophora  green  3.861470  1.648450  6.940588
#
#     glucose  oleic_acid
# 0  2.548459    6.405165
# 1  6.013219    4.156700
# 2  3.623225    0.304573
# 3  2.272724    3.393203
# 4  2.316955    2.528886

# %%
metrics = (concentrations
          .groupby('genus')
          .agg({'alanin': ['min', 'mean', 'max']}))

metrics
# Out:
#                alanin
#                   min      mean       max
# genus
# Ascophyllum  0.875429  0.875429  0.875429
# Cladophora   1.648450  3.997055  6.881024
# Fucus        0.346431  3.566411  6.641303
# Palmaria     3.176440  3.176440  3.176440
# Saccharina   1.255251  3.524207  5.793163

# %% [markdown]
# ## ![image.png](attachment:9c5df14e-ec70-446c-bfa0-9564da82e4c7.png)

# %%
concentrations.group.unique()
concentrations.head()
# Out:
#                species       genus  group   sucrose    alanin   citrate  \
# 0    Fucus_vesiculosus       Fucus  brown  3.001472  3.711498  5.004262
# 1  Saccharina_japonica  Saccharina  brown  6.731070  1.255251  5.621499
# 2       Fucus_serratus       Fucus  brown  3.276870  0.346431  1.216767
# 3      Fucus_distichus       Fucus  brown  6.786996  6.641303  6.423606
# 4    Cladophora_fracta  Cladophora  green  3.861470  1.648450  6.940588
#
#     glucose  oleic_acid
# 0  2.548459    6.405165
# 1  6.013219    4.156700
# 2  3.623225    0.304573
# 3  2.272724    3.393203
# 4  2.316955    2.528886

# %%
# point 1 - range = max concentration sucrose subtract min concentration sucrose
def concentr_range(x):
    return x.max() - x.min()

(concentrations
.groupby('group')
.agg({'sucrose': concentr_range}))
# Out:
#         sucrose
# group
# brown  5.189345
# green  3.259662
# red    0.000000

# %%
# point 2 - count types - group
(concentrations['group'].value_counts())
# Out:
# brown    6
# green    3
# red      1
# Name: group, dtype: int64

# %%
# poind 3 - varion concentration citrate in different type
(concentrations
.groupby('group')
.agg({'citrate': 'var'}))
# Out:
#         citrate
# group
# brown  5.468942
# green  3.950113
# red         NaN
